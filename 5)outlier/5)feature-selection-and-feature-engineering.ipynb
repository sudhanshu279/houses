# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/Users/apple/Documents/abc/Capstone_project/outlier/5)gurgaon_properties_missing_value_imputation.csv')

# %%
df.shape
# Out:
# (3554, 19)

# %%
df.head()
# Out:
#    Unnamed: 0 property_type                      society      sector  price  \
# 0           0          flat      signature global park 4   sector 36   0.82
# 1           1          flat             smart world gems   sector 89   0.95
# 2           3          flat       breez global hill view  sohna road   0.32
# 3           4          flat  bestech park view sanskruti   sector 92   1.60
# 4           5          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 0          7586.0        3         2       2       2.0    New Property
# 1          8597.0        2         2       2       4.0    New Property
# 2          5470.0        2         2       1      17.0    New Property
# 3          8020.0        3         4      3+      10.0  Relatively New
# 4          9023.0        2         2       1       5.0  Relatively New
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# ...

# %%
train_df = df.drop(columns=['society','price_per_sqft'])

# %%
train_df.head()
# Out:
#    Unnamed: 0 property_type      sector  price  bedRoom  bathroom balcony  \
# 0           0          flat   sector 36   0.82        3         2       2
# 1           1          flat   sector 89   0.95        2         2       2
# 2           3          flat  sohna road   0.32        2         2       1
# 3           4          flat   sector 92   1.60        3         4      3+
# 4           5          flat  sector 102   0.48        2         2       1
#
#    floorNum   agePossession  built_up_area  study room  servant room  \
# 0       2.0    New Property          850.0           0             0
# 1       4.0    New Property         1226.0           1             1
# 2      17.0    New Property         1000.0           0             0
# 3      10.0  Relatively New         1615.0           0             1
# 4       5.0  Relatively New          582.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# ...

# %%
sns.heatmap(train_df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
train_df.corr(numeric_only=True)['price'].sort_values(ascending=False)
# Out:
# price              1.000000
# built_up_area      0.748574
# bathroom           0.609777
# bedRoom            0.591289
# servant room       0.391930
# pooja room         0.319852
# store room         0.305677
# study room         0.242955
# furnishing_type    0.115194
# luxury_score       0.091473
# Unnamed: 0         0.011690
# others            -0.013064
# floorNum          -0.087442
# Name: price, dtype: float64

# %%
# cols in question

# numerical -> luxury_score, others, floorNum
# categorical -> property_type, sector, agePossession
